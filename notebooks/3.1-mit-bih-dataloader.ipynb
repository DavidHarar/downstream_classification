# %%
import numpy as np
import torch
from sklearn.preprocessing import MinMaxScaler
from typing import List
import json
import random

# %%
import os
root = '/home/david/Desktop/projects/thesis/downstream_classification/'
data_folder = '/data/mit-bih/processed'

os.listdir(root+data_folder)
# Out:
# ['08219_interval_14_labeled_N.npy',
#  '08434_interval_4_labeled_N.npy',
#  '04908_interval_13_labeled_AFIB.npy',
#  '04043_interval_106_labeled_N.npy',
#  '04043_interval_16_labeled_N.npy',
#  '04043_interval_100_labeled_N.npy',
#  '04936_interval_27_labeled_AFIB.npy',
#  '08219_interval_16_labeled_N.npy',
#  '06426_interval_33_labeled_AFIB.npy',
#  '05261_interval_19_labeled_AFIB.npy',
#  '04043_interval_73_labeled_AFIB.npy',
#  '04043_interval_57_labeled_AFIB.npy',
#  '08378_interval_7_labeled_AFIB.npy',
#  '08219_interval_36_labeled_N.npy',
#  '05121_interval_22_labeled_N.npy',
#  '06995_interval_9_labeled_N.npy',
#  '04043_interval_78_labeled_N.npy',
#  '05121_interval_9_labeled_AFIB.npy',
#  '04936_interval_21_labeled_AFIB.npy',
#  '04936_interval_53_labeled_AFIB.npy',
#  '04126_interval_5_labeled_AFIB.npy',
#  '05121_interval_11_labeled_AFIB.npy',
#  '04043_interval_46_labeled_N.npy',
#  '04043_interval_53_labeled_AFIB.npy',
#  '04936_interval_35_labeled_AFIB.npy',
#  '06426_interval_36_labeled_N.npy',
#  '04043_interval_19_labeled_AFIB.npy',
#  '05121_interval_16_labeled_N.npy',
#  '04048_interval_4_labeled_N.npy',
#  '04043_interval_10_labeled_N.npy',
#  '04043_interval_2_labeled_N.npy',
#  '05091_interval_4_labeled_N.npy',
#  '04015_interval_13_labeled_AFIB.npy',
#  '04908_interval_6_labeled_AFL.npy',
#  '05121_interval_13_labeled_AFIB.npy',
#  '05121_interval_21_labeled_AFIB.npy',
#  '05261_interval_7_labeled_AFIB.npy',
#  '04015_interval_8_labeled_N.npy',
#  '04048_interval_8_labeled_N.npy',
#  '04936_interval_45_labeled_AFIB.npy',
#  '08219_interval_31_labeled_AFIB.npy',
#  '04043_interval_123_labeled_AFIB.npy',
#  '05261_interval_13_labeled_AFIB.npy',
#  '06426_interval_49_labeled_AFIB.npy',
#  '04126_interval_1_labeled_AFIB.npy',
#  '07910_interval_9_labeled_AFIB.npy',
#  '05261_interval_12_labeled_N.npy',
#  '08219_interval_35_labeled_AFIB.npy',
#  '04936_interval_38_labeled_N.npy',
#  '04043_interval_161_labeled_N.npy',
#  '04043_interval_144_labeled_AFIB.npy',
#  '04936_interval_8_labeled_N.npy',
#  '04936_interval_46_labeled_N.npy',
#  '04908_interval_15_labeled_AFIB.npy',
#  '04043_interval_120_labeled_N.npy',
#  '08219_interval_5_labeled_AFIB.npy',
#  '05261_interval_8_labeled_N.npy',
#  '04043_interval_34_labeled_N.npy',
#  '04043_interval_28_labeled_N.npy',
#  '04043_interval_52_labeled_N.npy',
#  '06453_interval_12_labeled_N.npy',
#  '07879_interval_1_labeled_AFIB.npy',
#  '08219_interval_25_labeled_AFIB.npy',
#  '08219_interval_33_labeled_AFIB.npy',
#  '08219_interval_15_labeled_AFIB.npy',
#  '06426_interval_6_labeled_AFIB.npy',
#  '04043_interval_11_labeled_AFIB.npy',
#  '06426_interval_15_labeled_AFIB.npy',
#  '07879_interval_0_labeled_N.npy',
#  '06995_interval_4_labeled_AFIB.npy',
#  '07910_interval_2_labeled_N.npy',
#  '04936_interval_14_labeled_N.npy',
#  '06426_interval_30_labeled_N.npy',
#  '07910_interval_8_labeled_N.npy',
#  '04043_interval_85_labeled_AFIB.npy',
#  '04043_interval_72_labeled_N.npy',
#  '04043_interval_157_labeled_N.npy',
#  '05121_interval_30_labeled_J.npy',
#  '04043_interval_159_labeled_N.npy',
#  '08219_interval_76_labeled_N.npy',
#  '08378_interval_14_labeled_N.npy',
#  '04043_interval_21_labeled_AFIB.npy',
#  '06995_interval_1_labeled_AFL.npy',
#  '04043_interval_108_labeled_N.npy',
#  '04043_interval_69_labeled_AFIB.npy',
#  '08434_interval_2_labeled_N.npy',
#  '04043_interval_79_labeled_AFIB.npy',
#  '08455_interval_1_labeled_AFIB.npy',
#  '04936_interval_57_labeled_AFIB.npy',
#  '04043_interval_151_labeled_N.npy',
#  '04043_interval_18_labeled_N.npy',
#  '05121_interval_38_labeled_J.npy',
#  '08219_interval_57_labeled_AFIB.npy',
#  '05261_interval_9_labeled_AFIB.npy',
#  '06426_interval_53_labeled_N.npy',
#  '04015_interval_6_labeled_N.npy',
#  '04126_interval_9_labeled_AFIB.npy',
#  '08219_interval_32_labeled_N.npy',
#  '04043_interval_63_labeled_AFIB.npy',
#  '05121_interval_39_labeled_AFIB.npy',
#  '06426_interval_44_labeled_AFIB.npy',
#  '06426_interval_8_labeled_N.npy',
#  '04043_interval_74_labeled_N.npy',
#  '04043_interval_41_labeled_AFIB.npy',
#  '08219_interval_53_labeled_AFIB.npy',
#  '04043_interval_89_labeled_AFIB.npy',
#  '04048_interval_2_labeled_N.npy',
#  '04936_interval_42_labeled_N.npy',
#  '05121_interval_26_labeled_N.npy',
#  '05261_interval_2_labeled_N.npy',
#  '04043_interval_134_labeled_AFL.npy',
#  '06995_interval_3_labeled_AFL.npy',
#  '05261_interval_3_labeled_AFIB.npy',
#  '04936_interval_41_labeled_AFIB.npy',
#  '06426_interval_5_labeled_AFL.npy',
#  '08219_interval_62_labeled_N.npy',
#  '06426_interval_25_labeled_AFIB.npy',
#  '05121_interval_28_labeled_N.npy',
#  '06426_interval_41_labeled_AFIB.npy',
#  '06426_interval_3_labeled_N.npy',
#  '04043_interval_67_labeled_AFIB.npy',
#  '04936_interval_66_labeled_N.npy',
#  '04043_interval_163_labeled_N.npy',
#  '04908_interval_0_labeled_N.npy',
#  '04043_interval_146_labeled_AFIB.npy',
#  '04048_interval_12_labeled_N.npy',
#  '04043_interval_150_labeled_AFIB.npy',
#  '04908_interval_1_labeled_AFIB.npy',
#  '04043_interval_90_labeled_N.npy',
#  '08219_interval_66_labeled_N.npy',
#  '08219_interval_49_labeled_AFIB.npy',
#  '04126_interval_3_labeled_AFIB.npy',
#  '08219_interval_20_labeled_N.npy',
#  '04936_interval_52_labeled_N.npy',
#  '04043_interval_80_labeled_N.npy',
#  '08434_interval_1_labeled_AFIB.npy',
#  '08219_interval_3_labeled_AFIB.npy',
#  '04043_interval_165_labeled_N.npy',
#  '04043_interval_76_labeled_N.npy',
#  '06453_interval_5_labeled_AFIB.npy',
#  '04746_interval_9_labeled_AFIB.npy',
#  '08219_interval_70_labeled_N.npy',
#  '06426_interval_17_labeled_AFIB.npy',
#  '08219_interval_39_labeled_AFIB.npy',
#  '05121_interval_40_labeled_J.npy',
#  '04936_interval_12_labeled_N.npy',
#  '06453_interval_7_labeled_AFIB.npy',
#  '05091_interval_0_labeled_N.npy',
#  '04043_interval_92_labeled_N.npy',
#  '08378_interval_13_labeled_AFIB.npy',
#  '04126_interval_8_labeled_N.npy',
#  '04936_interval_17_labeled_AFIB.npy',
#  '07910_interval_7_labeled_AFIB.npy',
#  '04015_interval_10_labeled_N.npy',
#  '04043_interval_97_labeled_AFIB.npy',
#  '08219_interval_12_labeled_N.npy',
#  '04936_interval_6_labeled_N.npy',
#  '06426_interval_20_labeled_N.npy',
#  '04936_interval_63_labeled_AFIB.npy',
#  '04043_interval_164_labeled_AFIB.npy',
#  '08219_interval_19_labeled_AFIB.npy',
#  '05261_interval_22_labeled_N.npy',
#  '08219_interval_27_labeled_AFIB.npy',
#  '04126_interval_2_labeled_N.npy',
#  '04908_interval_4_labeled_N.npy',
#  '05121_interval_3_labeled_AFIB.npy',
#  '08219_interval_18_labeled_N.npy',
#  '08219_interval_64_labeled_N.npy',
#  '04936_interval_29_labeled_AFIB.npy',
#  '04746_interval_0_labeled_N.npy',
#  '04043_interval_23_labeled_AFIB.npy',
#  '08219_interval_52_labeled_N.npy',
#  '04936_interval_67_labeled_AFIB.npy',
#  '04126_interval_10_labeled_N.npy',
#  '04936_interval_50_labeled_N.npy',
#  '04043_interval_116_labeled_N.npy',
#  '05121_interval_19_labeled_AFIB.npy',
#  '05091_interval_11_labeled_AFIB.npy',
#  '04043_interval_1_labeled_AFIB.npy',
#  '04936_interval_54_labeled_N.npy',
#  '04043_interval_121_labeled_AFIB.npy',
#  '04043_interval_60_labeled_N.npy',
#  '08219_interval_6_labeled_N.npy',
#  '05261_interval_0_labeled_N.npy',
#  '08434_interval_6_labeled_N.npy',
#  '04936_interval_5_labeled_AFIB.npy',
#  '04936_interval_70_labeled_N.npy',
#  '07910_interval_4_labeled_AFL.npy',
#  '04043_interval_139_labeled_N.npy',
#  '05261_interval_1_labeled_AFIB.npy',
#  '04936_interval_2_labeled_N.npy',
#  '04043_interval_141_labeled_N.npy',
#  '08434_interval_5_labeled_AFIB.npy',
#  '04908_interval_2_labeled_N.npy',
#  '04746_interval_6_labeled_N.npy',
#  '05261_interval_17_labeled_AFIB.npy',
#  '07910_interval_0_labeled_N.npy',
#  '04043_interval_45_labeled_AFIB.npy',
#  '04015_interval_3_labeled_AFIB.npy',
#  '04936_interval_7_labeled_AFIB.npy',
#  '04936_interval_55_labeled_AFIB.npy',
#  '06426_interval_39_labeled_AFIB.npy',
#  '08215_interval_0_labeled_N.npy',
#  '08219_interval_51_labeled_AFIB.npy',
#  '04043_interval_125_labeled_AFIB.npy',
#  '04936_interval_23_labeled_AFIB.npy',
#  '04936_interval_25_labeled_AFIB.npy',
#  '06453_interval_2_labeled_N.npy',
#  '06426_interval_7_labeled_J.npy',
#  '05091_interval_2_labeled_N.npy',
#  '04936_interval_68_labeled_N.npy',
#  '04043_interval_104_labeled_N.npy',
#  '08219_interval_37_labeled_AFIB.npy',
#  '04043_interval_30_labeled_N.npy',
#  '08405_interval_3_labeled_AFIB.npy',
#  '05091_interval_6_labeled_N.npy',
#  '06426_interval_50_labeled_J.npy',
#  '04936_interval_13_labeled_AFIB.npy',
#  '04015_interval_2_labeled_N.npy',
#  '04043_interval_155_labeled_N.npy',
#  '04048_interval_7_labeled_AFIB.npy',
#  '08219_interval_26_labeled_N.npy',
#  '06426_interval_45_labeled_J.npy',
#  '04908_interval_16_labeled_N.npy',
#  '04043_interval_36_labeled_N.npy',
#  '04936_interval_71_labeled_AFIB.npy',
#  '08378_interval_16_labeled_N.npy',
#  '04048_interval_3_labeled_AFIB.npy',
#  '05121_interval_18_labeled_N.npy',
#  '08219_interval_4_labeled_N.npy',
#  '06995_interval_10_labeled_AFIB.npy',
#  '06426_interval_16_labeled_N.npy',
#  '04043_interval_119_labeled_AFIB.npy',
#  '05121_interval_6_labeled_N.npy',
#  '06426_interval_0_labeled_AFIB.npy',
#  '04043_interval_137_labeled_N.npy',
#  '05091_interval_16_labeled_N.npy',
#  '04043_interval_128_labeled_N.npy',
#  '06995_interval_5_labeled_N.npy',
#  '06426_interval_19_labeled_AFIB.npy',
#  '04043_interval_56_labeled_N.npy',
#  '04043_interval_75_labeled_AFIB.npy',
#  '04043_interval_95_labeled_AFIB.npy',
#  '04043_interval_55_labeled_AFIB.npy',
#  '08219_interval_8_labeled_N.npy',
#  '05121_interval_17_labeled_AFIB.npy',
#  '04043_interval_22_labeled_N.npy',
#  '04043_interval_54_labeled_N.npy',
#  '08219_interval_69_labeled_AFIB.npy',
#  '05261_interval_14_labeled_N.npy',
#  '05121_interval_20_labeled_N.npy',
#  '08378_interval_6_labeled_N.npy',
#  '04043_interval_133_labeled_AFIB.npy',
#  '04936_interval_36_labeled_N.npy',
#  '05261_interval_5_labeled_AFIB.npy',
#  '08378_interval_15_labeled_AFL.npy',
#  '04043_interval_101_labeled_AFIB.npy',
#  '04936_interval_20_labeled_N.npy',
#  '04936_interval_51_labeled_AFIB.npy',
#  '05121_interval_5_labeled_AFIB.npy',
#  '04043_interval_94_labeled_N.npy',
#  '04043_interval_44_labeled_N.npy',
#  '04043_interval_8_labeled_N.npy',
#  '04043_interval_20_labeled_N.npy',
#  '04048_interval_10_labeled_N.npy',
#  '04908_interval_12_labeled_AFL.npy',
#  '04936_interval_47_labeled_AFIB.npy',
#  '06995_interval_7_labeled_N.npy',
#  '04936_interval_30_labeled_N.npy',
#  '04043_interval_40_labeled_N.npy',
#  '04043_interval_82_labeled_N.npy',
#  '04043_interval_160_labeled_AFIB.npy',
#  '06453_interval_8_labeled_N.npy',
#  '06426_interval_47_labeled_AFIB.npy',
#  '08219_interval_7_labeled_AFIB.npy',
#  '04043_interval_62_labeled_N.npy',
#  '04043_interval_107_labeled_AFIB.npy',
#  '04043_interval_96_labeled_N.npy',
#  '08219_interval_54_labeled_N.npy',
#  '08219_interval_77_labeled_AFIB.npy',
#  '04043_interval_135_labeled_N.npy',
#  '06426_interval_51_labeled_N.npy',
#  '04043_interval_31_labeled_AFIB.npy',
#  '04043_interval_142_labeled_AFIB.npy',
#  '04043_interval_112_labeled_N.npy',
#  '04936_interval_31_labeled_AFIB.npy',
#  '04048_interval_14_labeled_N.npy',
#  '04043_interval_9_labeled_AFIB.npy',
#  '06426_interval_21_labeled_AFIB.npy',
#  '08219_interval_28_labeled_N.npy',
#  '04048_interval_5_labeled_AFIB.npy',
#  '04043_interval_117_labeled_AFIB.npy',
#  '08219_interval_2_labeled_N.npy',
#  '04936_interval_11_labeled_AFIB.npy',
#  '05121_interval_14_labeled_N.npy',
#  '04015_interval_1_labeled_AFIB.npy',
#  '04936_interval_58_labeled_N.npy',
#  '04936_interval_39_labeled_AFIB.npy',
#  '04908_interval_9_labeled_AFIB.npy',
#  '07910_interval_1_labeled_AFIB.npy',
#  '07879_interval_4_labeled_N.npy',
#  '08219_interval_1_labeled_AFIB.npy',
#  '04908_interval_10_labeled_AFL.npy',
#  '08219_interval_38_labeled_N.npy',
#  '04126_interval_14_labeled_N.npy',
#  '05121_interval_0_labeled_N.npy',
#  '05121_interval_7_labeled_AFIB.npy',
#  '04043_interval_26_labeled_N.npy',
#  '08219_interval_45_labeled_AFIB.npy',
#  '05091_interval_3_labeled_AFIB.npy',
#  '08219_interval_22_labeled_N.npy',
#  '04043_interval_71_labeled_AFIB.npy',
#  '04043_interval_38_labeled_N.npy',
#  '06426_interval_26_labeled_N.npy',
#  '05091_interval_5_labeled_AFIB.npy',
#  '04936_interval_43_labeled_AFIB.npy',
#  '04043_interval_3_labeled_AFIB.npy',
#  '08215_interval_2_labeled_AFL.npy',
#  '05261_interval_6_labeled_N.npy',
#  '04043_interval_12_labeled_N.npy',
#  '06426_interval_37_labeled_AFIB.npy',
#  '05121_interval_29_labeled_AFIB.npy',
#  '05121_interval_25_labeled_AFIB.npy',
#  '08434_interval_0_labeled_N.npy',
#  '04043_interval_124_labeled_N.npy',
#  '08219_interval_73_labeled_AFIB.npy',
#  '04015_interval_5_labeled_AFIB.npy',
#  '04048_interval_0_labeled_N.npy',
#  '06426_interval_29_labeled_AFIB.npy',
#  '04936_interval_26_labeled_N.npy',
#  '07879_interval_2_labeled_J.npy',
#  '07910_interval_5_labeled_AFIB.npy',
#  '08219_interval_42_labeled_N.npy',
#  '04746_interval_2_labeled_N.npy',
#  '05091_interval_13_labeled_AFIB.npy',
#  '04936_interval_60_labeled_N.npy',
#  '06426_interval_27_labeled_AFIB.npy',
#  '04126_interval_11_labeled_AFIB.npy',
#  '05121_interval_37_labeled_AFIB.npy',
#  '08215_interval_1_labeled_AFIB.npy',
#  '08405_interval_1_labeled_AFIB.npy',
#  '04043_interval_127_labeled_AFIB.npy',
#  '08219_interval_17_labeled_AFIB.npy',
#  '04043_interval_14_labeled_N.npy',
#  '04043_interval_122_labeled_N.npy',
#  '04043_interval_136_labeled_AFIB.npy',
#  '08219_interval_34_labeled_N.npy',
#  '04936_interval_37_labeled_AFIB.npy',
#  '05091_interval_9_labeled_AFIB.npy',
#  '06426_interval_4_labeled_AFIB.npy',
#  '06426_interval_46_labeled_N.npy',
#  '04043_interval_153_labeled_N.npy',
#  '08378_interval_8_labeled_N.npy',
#  '08219_interval_68_labeled_N.npy',
#  '04048_interval_13_labeled_AFIB.npy',
#  '04936_interval_24_labeled_N.npy',
#  '08378_interval_11_labeled_AFIB.npy',
#  '08405_interval_2_labeled_N.npy',
#  '04043_interval_138_labeled_AFIB.npy',
#  '04043_interval_37_labeled_AFIB.npy',
#  '05121_interval_35_labeled_AFIB.npy',
#  '06453_interval_3_labeled_AFIB.npy',
#  '04936_interval_4_labeled_N.npy',
#  '05121_interval_2_labeled_N.npy',
#  '06426_interval_13_labeled_AFIB.npy',
#  '05261_interval_21_labeled_AFIB.npy',
#  '08378_interval_2_labeled_N.npy',
#  '04126_interval_6_labeled_N.npy',
#  '08378_interval_1_labeled_AFL.npy',
#  '04043_interval_99_labeled_AFIB.npy',
#  '04936_interval_28_labeled_N.npy',
#  '05261_interval_16_labeled_N.npy',
#  '08434_interval_3_labeled_AFIB.npy',
#  '06426_interval_48_labeled_N.npy',
#  '04043_interval_111_labeled_AFIB.npy',
#  '08219_interval_46_labeled_N.npy',
#  '04043_interval_24_labeled_N.npy',
#  '08378_interval_3_labeled_AFIB.npy',
#  '04746_interval_8_labeled_N.npy',
#  '05121_interval_24_labeled_N.npy',
#  '08455_interval_2_labeled_N.npy',
#  '05121_interval_15_labeled_AFIB.npy',
#  '08219_interval_65_labeled_AFIB.npy',
#  '06426_interval_10_labeled_N.npy',
#  '08219_interval_56_labeled_N.npy',
#  '04043_interval_102_labeled_N.npy',
#  '08378_interval_10_labeled_N.npy',
#  '06426_interval_11_labeled_AFIB.npy',
#  '06426_interval_24_labeled_N.npy',
#  '04043_interval_147_labeled_N.npy',
#  '04043_interval_68_labeled_N.npy',
#  '08378_interval_4_labeled_N.npy',
#  '04043_interval_88_labeled_N.npy',
#  '08219_interval_23_labeled_AFIB.npy',
#  '04936_interval_15_labeled_AFIB.npy',
#  '04043_interval_5_labeled_AFIB.npy',
#  '04043_interval_158_labeled_AFIB.npy',
#  '06426_interval_18_labeled_N.npy',
#  '08219_interval_59_labeled_AFIB.npy',
#  '04015_interval_4_labeled_N.npy',
#  '08219_interval_40_labeled_N.npy',
#  '05121_interval_27_labeled_AFIB.npy',
#  '08455_interval_0_labeled_N.npy',
#  '05091_interval_14_labeled_N.npy',
#  '08219_interval_50_labeled_N.npy',
#  '04043_interval_61_labeled_AFIB.npy',
#  '04043_interval_13_labeled_AFIB.npy',
#  '06995_interval_6_labeled_AFIB.npy',
#  '08219_interval_67_labeled_AFIB.npy',
#  '05261_interval_15_labeled_AFIB.npy',
#  '04043_interval_65_labeled_AFIB.npy',
#  '05261_interval_20_labeled_N.npy',
#  '04936_interval_1_labeled_AFIB.npy',
#  '05121_interval_4_labeled_N.npy',
#  '04043_interval_115_labeled_AFIB.npy',
#  '08219_interval_44_labeled_N.npy',
#  '08219_interval_72_labeled_N.npy',
#  '08378_interval_12_labeled_N.npy',
#  '04043_interval_39_labeled_AFIB.npy',
#  '06426_interval_12_labeled_N.npy',
#  '04048_interval_11_labeled_AFIB.npy',
#  '08378_interval_9_labeled_AFIB.npy',
#  '04126_interval_4_labeled_N.npy',
#  '06453_interval_4_labeled_N.npy',
#  '04043_interval_98_labeled_N.npy',
#  '04043_interval_51_labeled_AFIB.npy',
#  '04043_interval_143_labeled_N.npy',
#  '04043_interval_59_labeled_AFIB.npy',
#  '04936_interval_19_labeled_AFIB.npy',
#  '04043_interval_140_labeled_AFIB.npy',
#  '04936_interval_64_labeled_N.npy',
#  '04043_interval_50_labeled_N.npy',
#  '04043_interval_156_labeled_AFIB.npy',
#  '06426_interval_9_labeled_AFIB.npy',
#  '04043_interval_25_labeled_AFIB.npy',
#  '04043_interval_47_labeled_AFIB.npy',
#  '06426_interval_40_labeled_N.npy',
#  '04043_interval_113_labeled_AFIB.npy',
#  '04936_interval_59_labeled_AFIB.npy',
#  '05121_interval_31_labeled_AFIB.npy',
#  '06426_interval_2_labeled_AFIB.npy',
#  '04043_interval_70_labeled_N.npy',
#  '08219_interval_0_labeled_N.npy',
#  '06426_interval_22_labeled_N.npy',
#  '08378_interval_5_labeled_AFL.npy',
#  '04043_interval_105_labeled_AFIB.npy',
#  '04908_interval_3_labeled_AFIB.npy',
#  '05121_interval_36_labeled_J.npy',
#  '04936_interval_18_labeled_N.npy',
#  '04015_interval_12_labeled_N.npy',
#  '04043_interval_81_labeled_AFIB.npy',
#  '04936_interval_40_labeled_N.npy',
#  '04043_interval_7_labeled_AFIB.npy',
#  'splits.json',
#  '08219_interval_60_labeled_N.npy',
#  '04048_interval_9_labeled_AFIB.npy',
#  '08219_interval_61_labeled_AFIB.npy',
#  '06426_interval_35_labeled_AFIB.npy',
#  '08219_interval_29_labeled_AFIB.npy',
#  '04043_interval_130_labeled_N.npy',
#  '04936_interval_9_labeled_AFIB.npy',
#  '04936_interval_32_labeled_N.npy',
#  '06453_interval_1_labeled_AFIB.npy',
#  '04043_interval_35_labeled_AFIB.npy',
#  '08455_interval_3_labeled_AFIB.npy',
#  '04936_interval_44_labeled_N.npy',
#  '04936_interval_33_labeled_AFIB.npy',
#  '04043_interval_148_labeled_AFIB.npy',
#  '04015_interval_0_labeled_N.npy',
#  '04043_interval_42_labeled_N.npy',
#  '05121_interval_33_labeled_AFIB.npy',
#  '04936_interval_0_labeled_N.npy',
#  '04908_interval_5_labeled_AFIB.npy',
#  '04126_interval_13_labeled_AFIB.npy',
#  '04936_interval_61_labeled_AFIB.npy',
#  '06995_interval_2_labeled_AFIB.npy',
#  '06426_interval_34_labeled_N.npy',
#  '04936_interval_49_labeled_AFIB.npy',
#  '04746_interval_7_labeled_AFIB.npy',
#  '06426_interval_42_labeled_J.npy',
#  '04126_interval_12_labeled_N.npy',
#  '04015_interval_11_labeled_AFIB.npy',
#  '08219_interval_24_labeled_N.npy',
#  '08219_interval_13_labeled_AFIB.npy',
#  '04043_interval_129_labeled_AFIB.npy',
#  '08215_interval_3_labeled_AFIB.npy',
#  '04015_interval_14_labeled_N.npy',
#  '05091_interval_8_labeled_N.npy',
#  '04043_interval_4_labeled_N.npy',
#  '06426_interval_23_labeled_AFIB.npy',
#  '08219_interval_75_labeled_AFIB.npy',
#  '08219_interval_10_labeled_N.npy',
#  '05261_interval_4_labeled_N.npy',
#  '06995_interval_0_labeled_AFIB.npy',
#  '05121_interval_23_labeled_AFIB.npy',
#  '05121_interval_8_labeled_N.npy',
#  '04746_interval_4_labeled_N.npy',
#  '06453_interval_10_labeled_N.npy',
#  '06453_interval_11_labeled_AFIB.npy',
#  '04043_interval_118_labeled_N.npy',
#  '04043_interval_29_labeled_AFIB.npy',
#  '04908_interval_14_labeled_N.npy',
#  '04043_interval_152_labeled_AFIB.npy',
#  '04043_interval_6_labeled_N.npy',
#  '07910_interval_6_labeled_N.npy',
#  '06426_interval_28_labeled_N.npy',
#  '04043_interval_114_labeled_N.npy',
#  '06426_interval_1_labeled_N.npy',
#  '05121_interval_1_labeled_AFIB.npy',
#  '04043_interval_103_labeled_AFIB.npy',
#  '04043_interval_84_labeled_N.npy',
#  '08219_interval_11_labeled_AFIB.npy',
#  '04936_interval_10_labeled_N.npy',
#  '04043_interval_110_labeled_N.npy',
#  '08219_interval_74_labeled_N.npy',
#  '05261_interval_18_labeled_N.npy',
#  '06426_interval_43_labeled_N.npy',
#  '04043_interval_132_labeled_N.npy',
#  '04043_interval_48_labeled_N.npy',
#  '04043_interval_43_labeled_AFIB.npy',
#  '04043_interval_154_labeled_AFIB.npy',
#  '04043_interval_93_labeled_AFIB.npy',
#  '04043_interval_33_labeled_AFIB.npy',
#  '05121_interval_10_labeled_N.npy',
#  '08378_interval_0_labeled_N.npy',
#  '05091_interval_15_labeled_AFIB.npy',
#  '06426_interval_54_labeled_AFIB.npy',
#  '04043_interval_32_labeled_N.npy',
#  '06426_interval_52_labeled_AFIB.npy',
#  '04908_interval_8_labeled_AFL.npy',
#  '04043_interval_66_labeled_N.npy',
#  '04908_interval_11_labeled_AFIB.npy',
#  '04936_interval_69_labeled_AFIB.npy',
#  '05121_interval_12_labeled_N.npy',
#  '04043_interval_15_labeled_AFIB.npy',
#  '04048_interval_1_labeled_AFIB.npy',
#  '04043_interval_149_labeled_N.npy',
#  '04126_interval_0_labeled_N.npy',
#  '04043_interval_77_labeled_AFIB.npy',
#  '06426_interval_31_labeled_AFIB.npy',
#  '04043_interval_145_labeled_N.npy',
#  '08219_interval_30_labeled_N.npy',
#  '04043_interval_91_labeled_AFIB.npy',
#  '08219_interval_9_labeled_AFIB.npy',
#  '04043_interval_109_labeled_AFIB.npy',
#  '08219_interval_78_labeled_N.npy',
#  '04043_interval_87_labeled_AFIB.npy',
#  '04936_interval_56_labeled_N.npy',
#  '05091_interval_12_labeled_N.npy',
#  '08219_interval_21_labeled_AFIB.npy',
#  '04043_interval_49_labeled_AFIB.npy',
#  '06426_interval_32_labeled_N.npy',
#  '08219_interval_47_labeled_AFIB.npy',
#  '04043_interval_58_labeled_N.npy',
#  '08219_interval_71_labeled_AFIB.npy',
#  '04043_interval_162_labeled_AFIB.npy',
#  '04746_interval_10_labeled_N.npy',
#  '08405_interval_0_labeled_N.npy',
#  '05091_interval_1_labeled_AFIB.npy',
#  '04936_interval_65_labeled_AFIB.npy',
#  '06995_interval_8_labeled_AFIB.npy',
#  '04126_interval_7_labeled_AFIB.npy',
#  '04746_interval_1_labeled_AFIB.npy',
#  '08219_interval_43_labeled_AFIB.npy',
#  '05121_interval_41_labeled_N.npy',
#  '08219_interval_63_labeled_AFIB.npy',
#  '05121_interval_32_labeled_J.npy',
#  '06426_interval_14_labeled_J.npy',
#  '04043_interval_131_labeled_AFIB.npy',
#  '05121_interval_34_labeled_J.npy',
#  '04043_interval_27_labeled_AFIB.npy',
#  '04936_interval_34_labeled_N.npy',
#  '08219_interval_48_labeled_N.npy',
#  '08219_interval_55_labeled_AFIB.npy',
#  '04908_interval_7_labeled_AFIB.npy',
#  '04746_interval_5_labeled_AFIB.npy',
#  '04043_interval_17_labeled_AFIB.npy',
#  '06453_interval_6_labeled_N.npy',
#  '04015_interval_7_labeled_AFIB.npy',
#  '05261_interval_11_labeled_AFIB.npy',
#  '05091_interval_10_labeled_N.npy',
#  '04936_interval_48_labeled_N.npy',
#  '07910_interval_3_labeled_AFIB.npy',
#  '04015_interval_9_labeled_AFIB.npy',
#  '04936_interval_62_labeled_N.npy',
#  '04043_interval_64_labeled_N.npy',
#  '05261_interval_10_labeled_N.npy',
#  '06453_interval_0_labeled_N.npy',
#  '08219_interval_41_labeled_AFIB.npy',
#  '08219_interval_58_labeled_N.npy',
#  '04936_interval_72_labeled_AFL.npy',
#  '05091_interval_7_labeled_AFIB.npy',
#  '04043_interval_86_labeled_N.npy',
#  '06426_interval_38_labeled_N.npy',
#  '07879_interval_3_labeled_AFIB.npy',
#  '04043_interval_126_labeled_N.npy',
#  '04043_interval_0_labeled_N.npy',
#  '04936_interval_3_labeled_AFIB.npy',
#  '04048_interval_6_labeled_N.npy',
#  '04936_interval_22_labeled_N.npy',
#  '04043_interval_83_labeled_AFIB.npy',
#  '06453_interval_9_labeled_AFIB.npy',
#  '04936_interval_16_labeled_N.npy',
#  '04746_interval_3_labeled_AFIB.npy']

# %%
class MIT_BIH_DataGen():
    def __init__(self, data_path, readings, batch_size, window_size = 450):
        
        assert (batch_size % 10) == 0, 'batch_size has to be a multiplication of 10'

        # store to self
        self.readings = readings
        self.batch_size = int(batch_size/10)
        self.window_size = window_size
        self.data_path = data_path
        
        # get numpy files
        self.npy_files = [x for x in os.listdir(data_path) if x.endswith('.npy')]

        # get relevant files
        self.N_files = []
        self.AF_files = []
        # self.test_N_files = []
        # self.test_AF_files = []

        for reading_number in self.readings:
            intervals_for_reading_all = [x for x in self.npy_files if x.split('_')[0] == reading_number]

            intervals_for_reading_N = [x for x in intervals_for_reading_all if x.endswith('_N.npy')]
            intervals_for_reading_AF = [x for x in intervals_for_reading_all if x.endswith('_AFIB.npy')]
            
            self.N_files += intervals_for_reading_N
            self.AF_files += intervals_for_reading_AF
        
        # shuffle lists
        random.shuffle(self.N_files)
        random.shuffle(self.AF_files)
        
        print('train_N_files[:5]:',self.N_files[:5])
        print('train_AF_files[:5]:',self.AF_files[:5])
        print('train_N_files Len:',len(self.N_files))
        print('train_AF_files Len:',len(self.AF_files))

        self.N_files = np.array(self.N_files)
        self.AF_files = np.array(self.AF_files)

    def __getitem__(self):
        """
        ASSUMPTIONS:
        - balanced batch each time
        - sample form five files each time, later versions can change that
        """
        batch_files_N  = np.random.choice(self.N_files, size=5, replace=True)
        batch_files_AF = np.random.choice(self.AF_files, size=5, replace=True)

        signals_in_batch = []
        targets_in_batch = []
        for filename in batch_files_N:
            interval = np.load(self.data_path+f'/{filename}')
            interval_length = len(interval)
            
            # draw window starts
            indices_to_draw_from = np.arange(interval_length-self.window_size-1)
            starts_of_signals = np.random.choice(indices_to_draw_from, size=self.batch_size, replace=False)
            
            # save signals
            signals_in_batch += [interval[start:(start+self.window_size)] for start in starts_of_signals]
            targets_in_batch += [0 for x in range(self.batch_size)]
        
        for filename in batch_files_AF:
            interval = np.load(self.data_path+f'/{filename}')
            interval_length = len(interval)
            
            # draw window starts
            indices_to_draw_from = np.arange(interval_length-self.window_size-1)
            starts_of_signals = np.random.choice(indices_to_draw_from, size=self.batch_size, replace=False)
            
            # save signals
            signals_in_batch += [interval[start:(start+self.window_size)] for start in starts_of_signals]
            targets_in_batch += [1 for _x in range(self.batch_size)]
        
        # combind signals with targets
        signals_and_targets_in_batch = [(signal, target) for (signal, target) in zip(signals_in_batch,targets_in_batch)]
        
        # shuffle
        random.shuffle(signals_and_targets_in_batch)

        # convert to np
        X = np.array([x[0] for x in signals_and_targets_in_batch])
        y = np.array([x[1] for x in signals_and_targets_in_batch])
        
        # transpose X
        X = np.transpose(X,(0,2,1))
        return X,y

# get splits
with open(root+data_folder+"/splits.json") as json_file:
    splits = json.load(json_file)

temp = MIT_BIH_DataGen(data_path=root+data_folder, readings=splits['train'], batch_size=10)
X,y = temp.__getitem__()

print('Shapes:', X.shape, y.shape)
print('y:', y)
# Out:
# train_N_files[:5]: ['08219_interval_30_labeled_N.npy', '04936_interval_46_labeled_N.npy', '04043_interval_130_labeled_N.npy', '04043_interval_90_labeled_N.npy', '06426_interval_43_labeled_N.npy']
# train_AF_files[:5]: ['08219_interval_31_labeled_AFIB.npy', '04043_interval_117_labeled_AFIB.npy', '04043_interval_9_labeled_AFIB.npy', '05121_interval_7_labeled_AFIB.npy', '04043_interval_115_labeled_AFIB.npy']
# train_N_files Len: 255
# train_AF_files Len: 260
# Shapes: (10, 2, 450) (10,)
# y: [1 0 0 1 0 1 0 1 0 1]

# %% [markdown]
# # Compare with SHL Data Gen

# %%
os.chdir('/home/david/Desktop/projects/thesis/downstream_classification')
from dataloader.DataGenerator import DataGenerator
train_generator = DataGenerator(
    data_folder_path='./data/individual-signals/',
    metadata_file_path='./data/combined_data/metadata_balanced_by_death.csv',
    targets=['AF'],
    sample='train',
    seed=123,
    batch_size=10,
    shuffle = True
)
X_shl, y_shl, signum_shl = train_generator.__getitem__(1)
print('Shapes:', X_shl.shape, y_shl.shape)
print('y:', y_shl)
# Out:
# Shapes: (10, 12, 450) (10, 1)
# y: [[0.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %% [markdown]
# # Summary
# In some of the experiments we run, we impute signals, freeze the upstream weights and basically only running the downstream weights. In these cases, we can just once, impute the downstream data and run it.

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns

# combined_model_train_only_downstream = pd.read_csv("/Users/davidharar/Documents/School/thesis/Writing/ptb-upstream-results.csv")
# display(combined_model_train_only_downstream)

# combined_model_train_both = pd.read_csv('/Users/davidharar/Documents/School/thesis/Writing/ptb-upstream-results-unfreeze_upstream_weights.csv')
# display(combined_model_train_both)

results_downstream = []
for channels in range(12):
    
    with open(f'/home/david/Desktop/projects/thesis/combined_downstream_upstream/models/ptb-{channels}_channels_off-no_additional_noise-impute_only_missing-cold_start/best_rocauc_and_pr_auc.pkl', 'rb') as handle:
        b = pickle.load(handle)
    bdf = pd.DataFrame(b)
    results_downstream.append(bdf)

results_downstream = pd.concat(results_downstream,axis=0,ignore_index=True)
results_downstream
# Out:
#     channels_to_turn_off  seed  validation-roc-auc  validation-pr-auc  \
# 0                      0   510            0.988407           0.900436
# 1                      0   365            0.987714           0.897297
# 2                      0   382            0.988711           0.898150
# 3                      0   322            0.987077           0.888452
# 4                      0   988            0.989145           0.905179
# ..                   ...   ...                 ...                ...
# 66                    11   510            0.968051           0.713414
# 67                    11   365            0.965791           0.693026
# 68                    11   382            0.967963           0.718501
# 69                    11   322            0.966223           0.686869
# 70                    11   988            0.966086           0.685076
#
#     test-roc-auc  test-pr-auc
# 0       0.986650     0.895569
# 1       0.985237     0.896166
# 2       0.985898     0.903532
# ...

# %%
# cresults_downstream.to_csv('/home/david/Desktop/projects/thesis/combined_downstream_upstream/notebooks/ptb-imputation-train_only_downstream-cold_start.csv',index=False)
